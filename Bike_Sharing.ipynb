# %% [markdown]
# <p align="center">
#     <span style="color:black; font-size:40px; font_weight:bold">Bike Sharing-Case Study: How Does a Bike-Share Navigate Speedy Success?</span>
# </p>

# %% [markdown]
# <p align="center">
# <span style="color:Black; font-size:30px; font_weight:bold">Google Data Analytics Professional Certificate program - Capstone Project</span>
# </p>
# <p align="center">
#   <img src="Screenshot 2023-12-07 at 17.46.45.png" alt="Company Logo">
# </p>

# %% [markdown]
# <span style="color:black; font-size:30px;"> About the Company (Cyclistic)</span>
#
# Cyclistic is a bike-share company launched in 2016 in Chicago. It has since grown to a fleet of 5,824 bicycles that are geo-tracked and locked into a network of 692 stations across Chicago. The bikes can be unlocked from one station and returned to any other station in the system anytime. Cyclistic offers a variety of pricing plans including: single-ride passes, full-day passes, and annual memberships.
#
# * **Customers who purchase a single-ride or full-day passes are referred to as casual riders.**
# * **Customers who purchase annual memberships are Cyclistic members.**
#
# Cyclistic’s finance analysts have concluded that annual members are much more profitable than casual riders. Although the pricing flexibility helps Cyclistic attract more customers, Moreno (director of marketing) believes that maximizing the number of annual members will be key to future growth. Rather than creating a marketing campaign that targets all-new customers, Moreno believes there is a very good chance to convert casual riders into members. She notes that casual riders are already aware of the Cyclistic program and have chosen Cyclistic for their mobility needs. Now, the goal is to design marketing strategies aimed at converting casual riders into annual members.
#
# <span style="color:black; font-size:30px;"> Objective </span>
#
# <span style="color:black; font-size:20px;"> Q: How do annual members and casual members use Cyclistic bikes differently?</span>
# - The aim is to explore and understand how annual members and casual riders differ and why casual riders would buy a membership!
#
#
# Some of the analysis guided in the case study to understand the data are:
# 1. Determining hte mean of ride_lenght
# 2. Determining the max ride_length
# 3. Determining hte mode of day of the week.
# 4. Determining the average ride_lenght for members and casual riders.
# 5. Determining the average ride_length for users by day of the week.
# 6. Determining the number of rides for users by day of the week.

# %% [markdown]
# <span style="color:black; font-size:30px;"> Data </span>
# ##### **Bike trip data from June 2020 to May 2021 has been studied to understand the use of bikes by different users (member and casual).**
# Link to the data: https://divvy-tripdata.s3.amazonaws.com/index.html
#
# The following information (columns) can be found in the data.
#
# 1. ride_id: Unique id assigned to a ride trip.
# 2. rideable_type: Type of bike used during trip by the user.
# 3. started_at: Start date and time for the trip
# 4. ended_at: End data and time for the trip
# 5. start_station_name: Name of the station where the trip started
# 6. start_station_id: Unique ID assigned to the start station.
# 7. end_station_name: Name of the station where the trip ended.
# 8. end_station_id: Unique ID assigned to the end station.
# 9. start_lat: Latitude of where the trip started.
# 10. start_lng: Longitude of where the trip started.
# 11. end_lat: Latitude of where the trip ended.
# 12. end_lng: Longitude of where the trip ended.
# 13. member_casual: User Type (either member or casual)

# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# ### Importing the 12 csv files (downloaded from the link given above).

# %%
f1 = pd.read_csv("/Users/bibekkadel/Documents/Bike Sharing/New_File/202006-divvy-tripdata.csv")
f2 = pd.read_csv("/Users/bibekkadel/Documents/Bike Sharing/New_File/202007-divvy-tripdata.csv")
f3 = pd.read_csv("/Users/bibekkadel/Documents/Bike Sharing/New_File/202008-divvy-tripdata.csv")
f4 = pd.read_csv("/Users/bibekkadel/Documents/Bike Sharing/New_File/202009-divvy-tripdata.csv")
f5 = pd.read_csv("/Users/bibekkadel/Documents/Bike Sharing/New_File/202010-divvy-tripdata.csv")
f6 = pd.read_csv("/Users/bibekkadel/Documents/Bike Sharing/New_File/202011-divvy-tripdata.csv")
f7 = pd.read_csv("/Users/bibekkadel/Documents/Bike Sharing/New_File/202012-divvy-tripdata.csv")
f8 = pd.read_csv("/Users/bibekkadel/Documents/Bike Sharing/New_File/202101-divvy-tripdata.csv")
f9 = pd.read_csv("/Users/bibekkadel/Documents/Bike Sharing/New_File/202102-divvy-tripdata.csv")
f10 = pd.read_csv("/Users/bibekkadel/Documents/Bike Sharing/New_File/202103-divvy-tripdata.csv")
f11 = pd.read_csv("/Users/bibekkadel/Documents/Bike Sharing/New_File/202104-divvy-tripdata.csv")
f12 = pd.read_csv("/Users/bibekkadel/Documents/Bike Sharing/New_File/202105-divvy-tripdata.csv")

# %% [markdown]
# ### Combining all the 12 files into 1 using concatenation.

# %%
all_files=[f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12]
file=pd.concat(all_files)
file.shape
# Out:
# (4073561, 13)

# %% [markdown]
# ### Understanding the datatypes, number of entries and null values present in the dataset.

# %%
file.info()

null = file.isnull().sum()
null_perc = null / file.shape[0] * 100
d_frame = pd.DataFrame({
    "Null Values": null,
    "Null Values Percentage": round(null_perc, 2)
})
print(d_frame)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4073561 entries, 0 to 531632
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 435.1+ MB
#                     Null Values  Null Values Percentage
# ride_id                       0                    0.00
# rideable_type                 0                    0.00
# started_at                    0                    0.00
# ended_at                      0                    0.00
# ...

# %% [markdown]
# ### Dropping the columns not needed for the analysis.
# There are multiple columns **['start_station_name', 'start_station_id', 'end_station_name', 'end_station_id', 'end_lat', 'end_lng']** with null values. But, as the objective of the analysis does not need the information that these columns have, these columns have been removed from the dataset. Further, columns **['start_lat'and 'start_lng']** also don't serve any purpose in this analysis, thus, are also removed from the dataset.

# %%
col = ['start_station_name', 'start_station_id', 'end_station_name', 'end_station_id', 'end_lat', 'end_lng','start_lat','start_lng']
file.drop(columns=col, inplace=True)
print(file.shape)
# Out:
# (4073561, 5)

# %% [markdown]
# ### Re-checkign the dataset information (number of entries, null values and null values percentage)

# %%
file.info()

null = file.isnull().sum()
null_perc = null / file.shape[0] * 100
new_d_frame = pd.DataFrame({
    "Null Values": null,
    "Null Values Percentage": round(null_perc, 2)
})
print(new_d_frame)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4073561 entries, 0 to 531632
# Data columns (total 5 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   ride_id        object
#  1   rideable_type  object
#  2   started_at     object
#  3   ended_at       object
#  4   member_casual  object
# dtypes: object(5)
# memory usage: 186.5+ MB
#                Null Values  Null Values Percentage
# ride_id                  0                     0.0
# rideable_type            0                     0.0
# started_at               0                     0.0
# ended_at                 0                     0.0
# member_casual            0                     0.0

# %% [markdown]
# ### Checking if there are any duplicates in the dataset.

# %%
dup = file.duplicated()
if any(dup):
    print("There are duplicate rows.")
else:
    print("No duplicate rows.")
# Out:
# No duplicate rows.

# %% [markdown]
# ### Converting the start_name and end_time into datetime format.

# %%
file["start_time"]=pd.to_datetime(file["started_at"])
file["end_time"]=pd.to_datetime(file["ended_at"])

# %% [markdown]
# ### Extract year, month, day, and day_name from 'start_time'

# %%
# from the start_time, creating new columns: year, month, day and day_name for easier analysis.
file['year'] = file['start_time'].dt.year
file['month'] = file['start_time'].dt.month
file['day'] = file['start_time'].dt.day
file['day_name'] = file['start_time'].dt.day_name()
file['hour'] = file['start_time'].dt.hour

# %% [markdown]
# ### Mapping the day names to numerical values (1-7)

# %%
# Mapping day names to numerical values
day_map = {'Sunday': 1, 'Monday': 2, 'Tuesday': 3, 'Wednesday': 4, 'Thursday': 5, 'Friday': 6, 'Saturday': 7}

file['day_number'] = file['day_name'].map(day_map)

# %% [markdown]
# ### Creating a new column named ride_lenght

# %%
file['ride_length']=file["end_time"]-file["start_time"]
file["ride_length"]
# Out:
# 0        0 days 00:12:07
# 1        0 days 00:05:48
# 2        0 days 00:08:33
# 3        0 days 00:18:49
# 4        0 days 00:09:23
#                ...
# 531628   0 days 00:03:25
# 531629   0 days 00:42:00
# 531630   0 days 00:06:44
# 531631   0 days 00:06:04
# 531632   0 days 00:08:13
# Name: ride_length, Length: 4073561, dtype: timedelta64[ns]

# %% [markdown]
# ### Viewing the head of the dataset

# %%
file.head(10)
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  8CD5DE2C2B6C4CFC   docked_bike  2020-06-13 23:24:48  2020-06-13 23:36:55
# 1  9A191EB2C751D85D   docked_bike  2020-06-26 07:26:10  2020-06-26 07:31:58
# 2  F37D14B0B5659BCF   docked_bike  2020-06-23 17:12:41  2020-06-23 17:21:14
# 3  C41237B506E85FA1   docked_bike  2020-06-20 01:09:35  2020-06-20 01:28:24
# 4  4B51B3B0BDA7787C   docked_bike  2020-06-25 16:59:25  2020-06-25 17:08:48
# 5  D50DF288196B53BE   docked_bike  2020-06-17 18:07:18  2020-06-17 18:18:14
# 6  165FA6D223E58600   docked_bike  2020-06-25 07:24:33  2020-06-25 07:31:11
# 7  D8236CFC050E591C   docked_bike  2020-06-19 00:00:56  2020-06-19 00:09:15
# 8  9D82B9B53C37C55C   docked_bike  2020-06-30 12:11:36  2020-06-30 12:32:43
# 9  3DFF4AB10A6895A3   docked_bike  2020-06-28 14:17:09  2020-06-28 14:27:51
#
#   member_casual          start_time            end_time  year  month  day  \
# ...

# %% [markdown]
# ### Finding the unique values in each column of the dataset.

# %%
file.nunique()
# Out:
# ride_id          4073352
# rideable_type          3
# started_at       3523583
# ended_at         3511499
# member_casual          2
# start_time       3523583
# end_time         3511499
# year                   2
# month                 12
# day                   31
# day_name               7
# hour                  24
# day_number             7
# ride_length        27329
# dtype: int64

# %% [markdown]
# ### Checking if the **ride_lenght** column has negative values.

# %%
negative_value = (file['ride_length'] < pd.Timedelta(0)).any()
negative_value
# Out:
# True

# %% [markdown]
# ### Checkign for the number of entries with negative ride_lenght values in the dataset.

# %%
negative_ride_lengths_count = (file['ride_length'] < pd.Timedelta(0)).sum()
print("Number of rows with negative ride_length:", negative_ride_lengths_count)
# Out:
# Number of rows with negative ride_length: 10336

# %% [markdown]
# ### Keeping only the rows with ride_lenght non-negative in the dataset (removing negative ride_lenght values)

# %%
file = file[file['ride_length'] >= pd.Timedelta(0)]
print("Number of rows after removing negative ride_length:", len(file))
# Out:
# Number of rows after removing negative ride_length: 4063225

# %% [markdown]
# ### Descriptive statistics of **ride_lenghts** column

# %%
file['ride_length'].describe()
# Out:
# count                      4063225
# mean     0 days 00:26:57.009098930
# std      0 days 03:56:57.840683717
# min                0 days 00:00:00
# 25%                0 days 00:07:42
# 50%                0 days 00:14:03
# 75%                0 days 00:25:54
# max               37 days 16:43:21
# Name: ride_length, dtype: object

# %% [markdown]
# ### Determining the number of member and casual riders.

# %%
casual_riders = file[file['member_casual'] == 'casual']['ride_id'].count()
member_riders = file[file['member_casual'] == 'member']['ride_id'].count()

print("Number of Casual Riders:", casual_riders)
print("Number of Member Riders:", member_riders)
# Out:
# Number of Casual Riders: 1710184
# Number of Member Riders: 2353041

# %% [markdown]
# ### Determining the mean **ride_length** of (1: all user, 2: member user, and 3: casual user)

# %%
mean_rl_total=file["ride_length"].mean()
mean_ride_length = file.groupby('member_casual')['ride_length'].mean()

print('The mean ride_lenght is:',mean_rl_total)
print()
print('The mean ride_lenght for each user type is:', mean_ride_length)

# Creating a horizontal bar chart
plt.figure(figsize=(8, 3))

# Plotting a horizontal bar chart
bars=plt.barh(mean_ride_length.index, mean_ride_length, color=['gray', 'orange'])
plt.title('Mean Ride Length by User Type')
plt.xlabel('Mean Ride Length')
plt.ylabel('User Type')
plt.tight_layout()
plt.show()
# Out:
# The mean ride_lenght is: 0 days 00:26:57.009098930
#
# The mean ride_lenght for each user type is: member_casual
# casual   0 days 00:42:41.781528186
# member   0 days 00:15:30.350986234
# Name: ride_length, dtype: timedelta64[ns]

# %% [markdown]
# ### Determining the max ride_lenght of rides from (1: all user, 2: member user, and 3: casual user)

# %%
max_rl_total=file["ride_length"].max()
max_ride_length = file.groupby('member_casual')['ride_length'].max()

print('The max ride_lenght (for all users) is:', max_rl_total)
print()
print('The max ride_lenght for each user type is:', max_ride_length)

# Creating a horizontal bar chart
plt.figure(figsize=(8, 3))

# Plotting a horizontal bar chart
bars=plt.barh(max_ride_length.index, max_ride_length, color=['gray', 'orange'])
plt.title('Max Ride Length by User Type')
plt.xlabel('Max Ride Length')
plt.ylabel('User Type')
plt.tight_layout()
plt.show()
# Out:
# The max ride_lenght (for all users) is: 37 days 16:43:21
#
# The max ride_lenght for each user type is: member_casual
# casual   37 days 16:43:21
# member   28 days 15:51:00
# Name: ride_length, dtype: timedelta64[ns]

# %% [markdown]
# ### Determining the mode of day of week for (1: all user, 2: member user, and 3: casual user)

# %%
# Calculating the mode of week_day for all types of users
mode_week_day = file["day_name"].mode()
print(mode_week_day)

# Calculating the mode of week_day for member user type
mode_week_day_member = file[file["member_casual"]=="member"]
mode_week_day_member = mode_week_day_member["day_name"].mode()
print(mode_week_day_member )

# Calculating the mode of week_day for casual user type
mode_week_day_casual = file[file["member_casual"]=="casual"]
mode_week_day_casual = mode_week_day_casual["day_name"].mode()
print(mode_week_day_casual)
# Out:
# 0    Saturday
# Name: day_name, dtype: object
# 0    Saturday
# Name: day_name, dtype: object
# 0    Saturday
# Name: day_name, dtype: object

# %% [markdown]
# ### Determining the number of member and casual riders each day of the week.

# %%
rides_user_type = file.groupby(['day_name', 'member_casual'])['ride_id'].count().reset_index()

pivot_table = rides_user_type.pivot(index='day_name', columns='member_casual', values='ride_id')

print(pivot_table)
# Out:
# member_casual  casual  member
# day_name
# Friday         246652  350586
# Monday         188417  315487
# Saturday       396428  360579
# Sunday         329948  307818
# Thursday       191762  341971
# Tuesday        174412  329416
# Wednesday      182565  347184

# %% [markdown]
# ### Bar-graph showing the number of riders (members and casuals) for each day of the week.

# %%
pivot_table = pivot_table.loc[['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']] ## loc is used to reorder the index of days to start from Sunday.

pivot_table.plot(kind='bar', figsize=(12, 5), color=['gray', 'orange'])
plt.title('Number of Riders for Each Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Riders')
plt.legend(title='User Type')
plt.xticks(rotation=0) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Determining the average ride_lenght of member and casual riders for each day of the week

# %%
avg_ride_per_day = file.groupby(['day_name', 'member_casual'])['ride_length'].mean().unstack()

ordered_days = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
ordered_data = avg_ride_per_day.loc[ordered_days]

print(ordered_data)
# Out:
# member_casual                    casual                    member
# day_name
# Sunday        0 days 00:48:53.476756943 0 days 00:17:28.038074446
# Monday        0 days 00:42:12.928684778 0 days 00:14:55.167651915
# Tuesday       0 days 00:38:00.142759672 0 days 00:14:34.394319037
# Wednesday     0 days 00:38:18.702199216 0 days 00:14:48.831242223
# Thursday      0 days 00:39:54.432744756 0 days 00:14:36.866128999
# Friday        0 days 00:40:30.170949353 0 days 00:15:12.867347811
# Saturday      0 days 00:44:34.033128336 0 days 00:16:59.489515473

# %% [markdown]
# ### Bar-graph showing the average ride lenght for each day of the week for riders (members and casuals).

# %%
avg_ride_per_day = avg_ride_per_day.loc[['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']]

# Plotting the bar graph
avg_ride_per_day.plot(kind='bar', figsize=(12, 5), color=['gray', 'orange'])
plt.title('Average Ride Length for Each Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Average Ride Length')
plt.legend(title='User Type')
plt.xticks(rotation=0)  
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bar-graph showing the number of rides per month for member and casual riders.

# %%
file['year_month'] = file['start_time'].dt.to_period('M')  # extracting the Year-Month in 'Period' format
rides_per_month_user = file.groupby(['year_month', 'member_casual'])['ride_id'].count().reset_index()

pivot_table = rides_per_month_user.pivot(index='year_month', columns='member_casual', values='ride_id')

pivot_table.sort_index(inplace=True) # Sorting the 'year_month' index in chronological order

pivot_table.plot(kind='bar', figsize=(14, 6), color=['gray', 'orange'])
plt.title('Number of Rides per Month for Member and Casual Riders')
plt.xlabel('Year, Month')
plt.ylabel('Number of Rides')
plt.legend(title='User Type')
plt.xticks(rotation=0) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Line Graph showing hte number of rides per hour for casual and member users.

# %%
rides_per_hour_user = file.groupby(['hour', 'member_casual'])['ride_id'].count().reset_index()

pivot_table = rides_per_hour_user.pivot(index='hour', columns='member_casual', values='ride_id').fillna(0)
plt.figure(figsize=(14, 6))
plt.plot(pivot_table.index, pivot_table['casual'], marker='o', label='Casual', color='skyblue')
plt.plot(pivot_table.index, pivot_table['member'], marker='o', label='Member', color='orange')

plt.title('Number of Rides per Hour for Casual and Member Users')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Rides')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Line Graphs for rides per hour per day for casual and rider user (7 different plots)

# %%
rides_per_hour_day = file.groupby(['hour', 'day_name', 'member_casual'])['ride_id'].count().reset_index() # grouping by hour, day_name and member_casual

fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(16, 8)) # as there are 7 days, creating subplots arranged in two rows. 
days_of_week = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']

for i, day in enumerate(days_of_week): # loop over each day (current day)
    day_data = rides_per_hour_day[rides_per_hour_day['day_name'] == day]
    
    pivot_table = day_data.pivot_table(index='hour', columns='member_casual', values='ride_id').fillna(0) # grouping for the current day.
    
    row = i // 4  
    col = i % 4   
    
    ax = axs[row, col]
    ax.plot(pivot_table.index, pivot_table['casual'], marker='o', label='Casual', color='gray')
    ax.plot(pivot_table.index, pivot_table['member'], marker='o', label='Member', color='orange')
    ax.set_title(f'{day}')
    ax.set_xlabel('Hour of the Day')
    ax.set_ylabel('Number of Rides')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Summarization of the observations and the recommendations**

# %% [markdown]
# <span style="color:black; font-size:16px;">
# <p>
# 1. In our dataset, we have 1,710,184 (42%) casual riders and 2,353,041 (58%) member riders
# <p>
# 2. There is an opportunity for the company to target these 42% customers to try to convert them to member riders as these customers serve better benefit to the company in longer run
# <p>
# 3. The casual riders have higher average ride_lenght than the member riders. However, the number of rides from member user is relatively higher compared to the number of rides from casual riders
# <p>
# 4. The analysis shows that Cyclistic usuage is high in all seasosn except winter. Hence, the marketing campaing should be more effective during the months except the winter period.
# <p>
# 5. It is only on Saturday and Sunday (weekends), the number of rides from casual riders are higher compared to the number of rides from member riders. Also, the number of rides from casual riders on Saturday and Sunday are almost double compared to the number of rides in weekdays.
# <p>
# 6. As there are more casual riders and they have higher average ride_lenght, coupouns could be introduced based on higher miles and the coupouns could be used in the purhcase of annual membership.
# <p>
# 7. Further, from the day wise hour wise plot, we can clearly see that member riders have spike on the usuage around 8 am and also on around 16 to 18  pm.This implies that member riders are using the rides to commute to work. They are using rides as a transport means to travel to work and return to home. However, in case of casual riders, the same cannot be said. The causal riders usuage have a linear increase from 5 am in the morning to until 18.
# <p>
# 8. On Saturday and Sunday, the graph shows similar trend for both member and casual riders with a linear increase from 5 am in the morning to until 13 - 14 pm. This can be traced down to the fact that people use rides for regular travels on weekends. Or we can say that as rides are being used by other user type as number of public transport (busses, metros, trains) are operated in less number in weekends.
# <p>
# 9. The analysis shows that marketing campaign can be targeted to casual riders to become member riders by focusing on the idea that they can use Cyclistic for their commute to work.
# <p>
# 10. Further, a complete data without any missing values for start station and end station would be helpful in more concise marketing target of casual riders based on the stations.
# </p>
# </span>
